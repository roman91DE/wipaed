# %%
import pandas as pd
from matplotlib import pyplot as plt
from bs4 import BeautifulSoup
import re

# %%
soup = BeautifulSoup(open("raw_html.txt", "r", encoding="utf-8"), 'html.parser')

# %%
table_body =

# %%
for child in soup.find("table", "nb list students_results").find("tbody").children:
    for row in child.find_all("tr"):
        print(row)
        print(".........................")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [84], line 2
#       1 for child in soup.find("table", "nb list students_results").find("tbody").children:
# ----> 2     for row in child.find_all("tr"):
#       3         print(row)
#       4         print(".........................")
#
# File ~/miniconda3/envs/dataScience/lib/python3.10/site-packages/bs4/element.py:965, in NavigableString.__getattr__(self, attr)
#     963     return self
#     964 else:
# --> 965     raise AttributeError(
#     966         "'%s' object has no attribute '%s'" % (
#     967             self.__class__.__name__, attr))
#
# AttributeError: 'NavigableString' object has no attribute 'find_all'

# %%
for row in table_rows:
    print(row.contents)
# Out:
# ['M.03.C52.2400']
# ['\n', <a href="#374328395022734" id="result_id_374328395022734" name="_374328395022734" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N374328395022734','Ergebnisdetails',800,600);">Corporate Finance Theory</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_374328395022734');
# 											   PopupLink.href='#374328395022734';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['2,7']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.996.3310']
# ['\n', <a href="#379615152579396" id="result_id_379615152579396" name="_379615152579396" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N379615152579396','Ergebnisdetails',800,600);">Computational Intelligence</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_379615152579396');
# 											   PopupLink.href='#379615152579396';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['1,0']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.08.079.555']
# ['\n', <a href="#375848155183930" id="result_id_375848155183930" name="_375848155183930" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N375848155183930','Ergebnisdetails',800,600);">Einführung in die Programmierung (Exp.)</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_375848155183930');
# 											   PopupLink.href='#375848155183930';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['1,0']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.08.079.565']
# ['\n', <a href="#378014819990474" id="result_id_378014819990474" name="_378014819990474" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N378014819990474','Ergebnisdetails',800,600);">Einführung in die Softwareentwicklung (Exp.)</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_378014819990474');
# 											   PopupLink.href='#378014819990474';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['2,0']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.184.4105']
# ['\n', <a href="#370764949350214" id="result_id_370764949350214" name="_370764949350214" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N370764949350214','Ergebnisdetails',800,600);">Mikroökonomie II</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_370764949350214');
# 											   PopupLink.href='#370764949350214';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['3,3']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.181.203a']
# ['\n', <a href="#372786463302459" id="result_id_372786463302459" name="_372786463302459" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N372786463302459','Ergebnisdetails',800,600);">Modul 2.03a: Lehr-Lern- und Unterweisungsprozesse II</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_372786463302459');
# 											   PopupLink.href='#372786463302459';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  8,0']
# ['  8,0']
# ['1,7']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.181.201']
# ['\n', <a href="#371605031585945" id="result_id_371605031585945" name="_371605031585945" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N371605031585945','Ergebnisdetails',800,600);">Berufs- und Wirtschaftspädagogik II: Theorien und Konzepte (Modul 2.01)</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_371605031585945');
# 											   PopupLink.href='#371605031585945';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['1,0']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.181.202']
# ['\n', <a href="#379827834198421" id="result_id_379827834198421" name="_379827834198421" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N379827834198421','Ergebnisdetails',800,600);">Modul 2.02: Unterweisungs- und unterrichtspraktische Studien II</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_379827834198421');
# 											   PopupLink.href='#379827834198421';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# [' 12,0']
# [' 12,0']
# ['1,3']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.181.204']
# ['\n', <a href="#383065995693739" id="result_id_383065995693739" name="_383065995693739" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N383065995693739','Ergebnisdetails',800,600);">Modul 2.04: Empirische Berufsbildungsforschung II</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_383065995693739');
# 											   PopupLink.href='#383065995693739';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['1,0']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.181.580']
# ['\n', <a href="#380774950280610" id="result_id_380774950280610" name="_380774950280610" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N380774950280610','Ergebnisdetails',800,600);">Personalauswahl</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_380774950280610');
# 											   PopupLink.href='#380774950280610';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['1,3']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.C52.1310']
# ['\n', <a href="#374328390198681" id="result_id_374328390198681" name="_374328390198681" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N374328390198681','Ergebnisdetails',800,600);">Corporate Governance deutscher Unternehmen</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_374328390198681');
# 											   PopupLink.href='#374328390198681';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['3,7']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.C52.1410']
# ['\n', <a href="#370764960528026" id="result_id_370764960528026" name="_370764960528026" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N370764960528026','Ergebnisdetails',800,600);">Performancemessung und Anreizgestaltung</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_370764960528026');
# 											   PopupLink.href='#370764960528026';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['4,0']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.C52.1340']
# ['\n', <a href="#372217170527898" id="result_id_372217170527898" name="_372217170527898" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N372217170527898','Ergebnisdetails',800,600);">Wirtschaftsprüfung</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_372217170527898');
# 											   PopupLink.href='#372217170527898';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['1,7']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.996.4110']
# ['\n', <a href="#370764953646960" id="result_id_370764953646960" name="_370764953646960" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N370764953646960','Ergebnisdetails',800,600);">International Market-Oriented Management</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_370764953646960');
# 											   PopupLink.href='#370764953646960';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['3,0']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.996.4140']
# ['\n', <a href="#372217166243911" id="result_id_372217166243911" name="_372217166243911" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N372217166243911','Ergebnisdetails',800,600);">Aufbaumodul International Management and Marketing IV: Market Research</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_372217166243911');
# 											   PopupLink.href='#372217166243911';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['2,0']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]
# ['M.03.996.4180']
# ['\n', <a href="#378023670476245" id="result_id_378023670476245" name="_378023670476245" onclick="javascript: dl_popUp('/scripts/mgrqispi.dll?APPNAME=CampusNet&amp;PRGNAME=RESULTDETAILS&amp;ARGUMENTS=-N591721198579516,-N000917,-N378023670476245','Ergebnisdetails',800,600);">Aufbaumodul International Management and Marketing V: Marketing Intelligence</a>, '\n', <script type="text/javascript">
# 											   <!--
# 											   var PopupLink=document.getElementById('result_id_378023670476245');
# 											   PopupLink.href='#378023670476245';
# 											   //-->
# 											   </script>, '\n']
# ['\xa0']
# ['  6,0']
# ['  6,0']
# ['4,0']
# ['\xa0']
# [<img alt="Bestanden" src="/img/individual/pass.gif" title="Bestanden"/>]

# %%
for tag in soup.find_all("td", "tbdata"):
    print(tag.content)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
pd.DataFrame.from_dict({
    "Corporate Finance Theory": {
        "CP": 6.0,
        "Grade": 2.7
    },
    "Computational Intelligence": {
        "CP": 6.0,
        "Grade": 1.0
    }
})
# Out:
#        Corporate Finance Theory  Computational Intelligence
# CP                          6.0                         6.0
# Grade                       2.7                         1.0
